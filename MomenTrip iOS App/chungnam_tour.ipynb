# %%
import pandas as pd
import json

# 판다스가 긴 텍스트나 행을 생략하지 않고 전부 보여주도록 설정
pd.set_option('display.max_columns', None)      # 모든 컬럼 표시
pd.set_option('display.max_rows', None)         # 모든 행(167개 전체) 표시
pd.set_option('display.max_colwidth', None)     # 긴 주소나 텍스트가 잘리지 않게 전체 표시

# CSV 파일 읽기 및 JSON 변환
df = pd.read_csv('충청남도_주요 관광정보_20231130.csv', encoding='cp949')
df.to_json('chungnam_tours.json', orient='records', force_ascii=False)

# 확인용 출력
print(f"총 {len(df)}개의 데이터가 정상적으로 변환되었습니다.")
print(df) # 이제 전체 내용이 잘리지 않고 출력됩니다.
# Out:
# 총 167개의 데이터가 정상적으로 변환되었습니다.
#       연번  시군명                 관광지명  \
# 0      1  천안시                독립기념관
# 1      2  천안시              천안삼거리공원
# 2      3  천안시             유관순열사사적지
# 3      4  천안시                  태조산
# 4      5  천안시                  각원사
# 5      6  천안시             봉선홍경사갈기비
# 6      7  천안시               홍대용과학관
# 7      8  천안시                  광덕산
# 8      9  천안시               성성호수공원
# 9     10  천안시             아라리오조각공원
# 10    11  공주시                  공산성
# 11    12  공주시          무령왕릉과 공주박물관
# 12    13  공주시                  마곡사
# 13    14  공주시             계룡산과 동학사
# 14    15  공주시                 고마나루
# 15    16  공주시                   갑사
# 16    17  공주시               석장리박물관
# 17    18  공주시               금학생태공원
# 18    19  공주시              메타쉐콰이어길
# 19    20  공주시           연미산 자연미술공원
# 20    21  공주시             유구색동수국정원
# 21    22  보령시               대천해수욕장
# 22    23  보령시              죽도(상화원)
# 23    24  보령시            성주산 자연휴양림
# 24    25  보령시               개화예술공원
# ...
